# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Juan Pablo Morales**
#
# Economist

# %% [markdown]
# *I'm interested in data science because I'm a curious person and I love to make economical research. I think this course can help me improve my analytical skills.*

# %% [markdown]
# ### A Simple Subtraction

# %%
print (25-12)
# Out:
# 13

# %% [markdown]
# 1. Milk
# 2. Eggs
# 3. Steak
# 4. Chicken
#
# header   |header   |header
# ---   |---   |---
# cell   |cell   |cell
